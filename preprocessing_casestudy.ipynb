# %% [markdown]
# <a href="https://colab.research.google.com/github/Aromal-801/mrar07/blob/main/preprocessing_casestudy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
House_Pricing = pd.read_csv('/content/House_Pricing.csv')
House_Pricing.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ... Overall Grade  \
# 0              No                 NaN  ...             7
# ...

# %%
House_Pricing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21613 non-null  int64
#  1   Date House was Sold                        21613 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21613 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21604 non-null  float64
#  6   Lot Area (in Sqft)                         21604 non-null  float64
#  7   No of Floors                               21613 non-null  float64
#  8   Waterfront View                            21613 non-null  object
#  9   No of Times Visited                        2124 non-null   object
# ...

# %%
House_Pricing.shape
# Out:
# (21613, 21)

# %%
House_Pricing.describe()
# Out:
#                  ID    Sale Price  No of Bedrooms  No of Bathrooms  \
# count  2.161300e+04  2.160900e+04    21613.000000     21609.000000
# mean   4.580302e+09  5.401984e+05        3.370842         2.114732
# std    2.876566e+09  3.673890e+05        0.930062         0.770138
# min    1.000102e+06  7.500000e+04        0.000000         0.000000
# 25%    2.123049e+09  3.219500e+05        3.000000         1.750000
# 50%    3.904930e+09  4.500000e+05        3.000000         2.250000
# 75%    7.308900e+09  6.450000e+05        4.000000         2.500000
# max    9.900000e+09  7.700000e+06       33.000000         8.000000
#
#        Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  Overall Grade  \
# count         21604.000000        2.160400e+04  21613.000000   21613.000000
# mean           2079.931772        1.510776e+04      1.494309       7.623467
# std             918.487597        4.142827e+04      0.539989       1.105439
# ...

# %%
House_Pricing.isnull().sum()
# Out:
# ID                                               0
# Date House was Sold                              0
# Sale Price                                       4
# No of Bedrooms                                   0
# No of Bathrooms                                  4
# Flat Area (in Sqft)                              9
# Lot Area (in Sqft)                               9
# No of Floors                                     0
# Waterfront View                                  0
# No of Times Visited                          19489
# Condition of the House                           0
# Overall Grade                                    0
# Area of the House from Basement (in Sqft)        3
# Basement Area (in Sqft)                          0
# Age of House (in Years)                          0
# Renovated Year                                   0
# Zipcode                                          1
# Latitude                                         1
# ...

# %%
House_Pricing.duplicated().sum()
# Out:
# np.int64(0)

# %%
House_Pricing.columns.duplicated().sum()
# Out:
# np.int64(0)

# %%
House_Pricing['Sale Price'] = House_Pricing['Sale Price'].fillna(House_Pricing['Sale Price'].mean())
House_Pricing['Flat Area (in Sqft)'] = House_Pricing['Flat Area (in Sqft)'].fillna(House_Pricing['Flat Area (in Sqft)'].median())

# %%
print(House_Pricing.isnull().sum())
# Out:
# ID                                               0
# Date House was Sold                              0
# Sale Price                                       0
# No of Bedrooms                                   0
# No of Bathrooms                                  4
# Flat Area (in Sqft)                              0
# Lot Area (in Sqft)                               9
# No of Floors                                     0
# Waterfront View                                  0
# No of Times Visited                          19489
# Condition of the House                           0
# Overall Grade                                    0
# Area of the House from Basement (in Sqft)        3
# Basement Area (in Sqft)                          0
# Age of House (in Years)                          0
# Renovated Year                                   0
# Zipcode                                          1
# Latitude                                         1
# ...

# %%
House_Pricing['No of Bathrooms'] = House_Pricing['No of Bathrooms'].fillna(House_Pricing['No of Bathrooms'].mean())
House_Pricing['No of Bathrooms']
# Out:
# 0        1.00
# 1        2.25
# 2        1.00
# 3        3.00
# 4        2.00
#          ...
# 21608    2.50
# 21609    2.50
# 21610    0.75
# 21611    2.50
# 21612    0.75
# Name: No of Bathrooms, Length: 21613, dtype: float64

# %%
House_Pricing['Flat Area (in Sqft)'] = House_Pricing['Flat Area (in Sqft)'].fillna(House_Pricing['Flat Area (in Sqft)'].mean())
House_Pricing['Flat Area (in Sqft)']
# Out:
# 0        1180.0
# 1        2570.0
# 2         770.0
# 3        1960.0
# 4        1680.0
#           ...
# 21608    1530.0
# 21609    2310.0
# 21610    1020.0
# 21611    1600.0
# 21612    1020.0
# Name: Flat Area (in Sqft), Length: 21613, dtype: float64

# %%
House_Pricing['Lot Area (in Sqft)'] = House_Pricing['Lot Area (in Sqft)'].fillna(House_Pricing['Lot Area (in Sqft)'].mean())
House_Pricing['Lot Area (in Sqft)']
# Out:
# 0         5650.0
# 1         7242.0
# 2        10000.0
# 3         5000.0
# 4         8080.0
#           ...
# 21608     1131.0
# 21609     5813.0
# 21610     1350.0
# 21611     2388.0
# 21612     1076.0
# Name: Lot Area (in Sqft), Length: 21613, dtype: float64

# %%
House_Pricing= House_Pricing.drop(columns=['No of Times Visited'])
House_Pricing
# Out:
#                ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0      7129300520     14 October 2017    221900.0               3
# 1      6414100192    14 December 2017    538000.0               3
# 2      5631500400    15 February 2016    180000.0               2
# 3      2487200875    14 December 2017    604000.0               4
# 4      1954400510    15 February 2016    510000.0               3
# ...           ...                 ...         ...             ...
# 21608   263000018         14 May 2017    360000.0               3
# 21609  6600060120    15 February 2016    400000.0               4
# 21610  1523300141        14 June 2017    402101.0               2
# 21611   291310100     15 January 2016    400000.0               3
# 21612  1523300157     14 October 2017    325000.0               2
#
#        No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0                 1.00               1180.0              5650.0           1.0
# ...

# %%
House_Pricing.isna().sum()
# Out:
# ID                                           0
# Date House was Sold                          0
# Sale Price                                   0
# No of Bedrooms                               0
# No of Bathrooms                              0
# Flat Area (in Sqft)                          0
# Lot Area (in Sqft)                           0
# No of Floors                                 0
# Waterfront View                              0
# Condition of the House                       0
# Overall Grade                                0
# Area of the House from Basement (in Sqft)    3
# Basement Area (in Sqft)                      0
# Age of House (in Years)                      0
# Renovated Year                               0
# Zipcode                                      1
# Latitude                                     1
# Longitude                                    1
# Living Area after Renovation (in Sqft)       1
# Lot Area after Renovation (in Sqft)          0
# dtype: int64

# %%
House_Pricing['Area of the House from Basement (in Sqft)'] =House_Pricing['Area of the House from Basement (in Sqft)'].fillna(House_Pricing['Area of the House from Basement (in Sqft)'].median())
House_Pricing['Area of the House from Basement (in Sqft)']
# Out:
# 0        1180.0
# 1        2170.0
# 2         770.0
# 3        1050.0
# 4        1680.0
#           ...
# 21608    1530.0
# 21609    2310.0
# 21610    1020.0
# 21611    1600.0
# 21612    1020.0
# Name: Area of the House from Basement (in Sqft), Length: 21613, dtype: float64

# %%
House_Pricing['Zipcode'] = House_Pricing ['Zipcode'].fillna(House_Pricing['Zipcode'].median())
House_Pricing['Zipcode']
# Out:
# 0        98178.0
# 1        98125.0
# 2        98028.0
# 3        98136.0
# 4        98074.0
#           ...
# 21608    98103.0
# 21609    98146.0
# 21610    98144.0
# 21611    98027.0
# 21612    98144.0
# Name: Zipcode, Length: 21613, dtype: float64

# %%
House_Pricing.shape
# Out:
# (21613, 20)

# %%
House_Pricing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 20 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21613 non-null  int64
#  1   Date House was Sold                        21613 non-null  object
#  2   Sale Price                                 21613 non-null  float64
#  3   No of Bedrooms                             21613 non-null  int64
#  4   No of Bathrooms                            21613 non-null  float64
#  5   Flat Area (in Sqft)                        21613 non-null  float64
#  6   Lot Area (in Sqft)                         21613 non-null  float64
#  7   No of Floors                               21613 non-null  float64
#  8   Waterfront View                            21613 non-null  object
#  9   Condition of the House                     21613 non-null  object
# ...

# %%
House_Pricing.describe()
# Out:
#                  ID    Sale Price  No of Bedrooms  No of Bathrooms  \
# count  2.161300e+04  2.161300e+04    21613.000000     21613.000000
# mean   4.580302e+09  5.401984e+05        3.370842         2.114732
# std    2.876566e+09  3.673550e+05        0.930062         0.770067
# min    1.000102e+06  7.500000e+04        0.000000         0.000000
# 25%    2.123049e+09  3.220000e+05        3.000000         1.750000
# 50%    3.904930e+09  4.500000e+05        3.000000         2.250000
# 75%    7.308900e+09  6.450000e+05        4.000000         2.500000
# max    9.900000e+09  7.700000e+06       33.000000         8.000000
#
#        Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  Overall Grade  \
# count         21613.000000        2.161300e+04  21613.000000   21613.000000
# mean           2079.861010        1.510776e+04      1.494309       7.623467
# std             918.302876        4.141964e+04      0.539989       1.105439
# ...

# %%
House_Pricing.duplicated().sum()
# Out:
# np.int64(0)

# %%
House_Pricing.columns.duplicated().sum()
# Out:
# np.int64(0)

# %%
House_Pricing.isna().sum()
# Out:
# ID                                           0
# Date House was Sold                          0
# Sale Price                                   0
# No of Bedrooms                               0
# No of Bathrooms                              0
# Flat Area (in Sqft)                          0
# Lot Area (in Sqft)                           0
# No of Floors                                 0
# Waterfront View                              0
# Condition of the House                       0
# Overall Grade                                0
# Area of the House from Basement (in Sqft)    0
# Basement Area (in Sqft)                      0
# Age of House (in Years)                      0
# Renovated Year                               0
# Zipcode                                      0
# Latitude                                     1
# Longitude                                    1
# Living Area after Renovation (in Sqft)       1
# Lot Area after Renovation (in Sqft)          0
# dtype: int64

# %%
House_Pricing['No of Bathrooms'] = House_Pricing['No of Bathrooms'].fillna(House_Pricing['No of Bathrooms'].mean())
House_Pricing['No of Bathrooms']
# Out:
# 0        1.00
# 1        2.25
# 2        1.00
# 3        3.00
# 4        2.00
#          ...
# 21608    2.50
# 21609    2.50
# 21610    0.75
# 21611    2.50
# 21612    0.75
# Name: No of Bathrooms, Length: 21613, dtype: float64

# %%
House_Pricing['Flat Area (in Sqft)'] = House_Pricing['Flat Area (in Sqft)'].fillna(House_Pricing['Flat Area (in Sqft)'].mean())
House_Pricing['Flat Area (in Sqft)']
# Out:
# 0        1180.0
# 1        2570.0
# 2         770.0
# 3        1960.0
# 4        1680.0
#           ...
# 21608    1530.0
# 21609    2310.0
# 21610    1020.0
# 21611    1600.0
# 21612    1020.0
# Name: Flat Area (in Sqft), Length: 21613, dtype: float64

# %%
House_Pricing['Lot Area (in Sqft)'] = House_Pricing['Lot Area (in Sqft)'].fillna(House_Pricing['Lot Area (in Sqft)'].mean())
House_Pricing['Lot Area (in Sqft)']
# Out:
# 0         5650.0
# 1         7242.0
# 2        10000.0
# 3         5000.0
# 4         8080.0
#           ...
# 21608     1131.0
# 21609     5813.0
# 21610     1350.0
# 21611     2388.0
# 21612     1076.0
# Name: Lot Area (in Sqft), Length: 21613, dtype: float64

# %%
House_Pricing
# Out:
#                ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0      7129300520     14 October 2017    221900.0               3
# 1      6414100192    14 December 2017    538000.0               3
# 2      5631500400    15 February 2016    180000.0               2
# 3      2487200875    14 December 2017    604000.0               4
# 4      1954400510    15 February 2016    510000.0               3
# ...           ...                 ...         ...             ...
# 21608   263000018         14 May 2017    360000.0               3
# 21609  6600060120    15 February 2016    400000.0               4
# 21610  1523300141        14 June 2017    402101.0               2
# 21611   291310100     15 January 2016    400000.0               3
# 21612  1523300157     14 October 2017    325000.0               2
#
#        No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0                 1.00               1180.0              5650.0           1.0
# ...

# %%
House_Pricing.isna().sum()
# Out:
# ID                                           0
# Date House was Sold                          0
# Sale Price                                   0
# No of Bedrooms                               0
# No of Bathrooms                              0
# Flat Area (in Sqft)                          0
# Lot Area (in Sqft)                           0
# No of Floors                                 0
# Waterfront View                              0
# Condition of the House                       0
# Overall Grade                                0
# Area of the House from Basement (in Sqft)    0
# Basement Area (in Sqft)                      0
# Age of House (in Years)                      0
# Renovated Year                               0
# Zipcode                                      0
# Latitude                                     1
# Longitude                                    1
# Living Area after Renovation (in Sqft)       1
# Lot Area after Renovation (in Sqft)          0
# dtype: int64

# %%
House_Pricing['Area of the House from Basement (in Sqft)'] = House_Pricing['Area of the House from Basement (in Sqft)'].fillna(House_Pricing['Area of the House from Basement (in Sqft)'].median())
House_Pricing['Area of the House from Basement (in Sqft)']
# Out:
# 0        1180.0
# 1        2170.0
# 2         770.0
# 3        1050.0
# 4        1680.0
#           ...
# 21608    1530.0
# 21609    2310.0
# 21610    1020.0
# 21611    1600.0
# 21612    1020.0
# Name: Area of the House from Basement (in Sqft), Length: 21613, dtype: float64

# %%
House_Pricing['Zipcode'] = House_Pricing['Zipcode'].fillna(House_Pricing['Zipcode'].median())
House_Pricing['Zipcode']
# Out:
# 0        98178.0
# 1        98125.0
# 2        98028.0
# 3        98136.0
# 4        98074.0
#           ...
# 21608    98103.0
# 21609    98146.0
# 21610    98144.0
# 21611    98027.0
# 21612    98144.0
# Name: Zipcode, Length: 21613, dtype: float64

# %%
House_Pricing['Latitude'] = House_Pricing['Latitude'].fillna(House_Pricing['Latitude'].median())
House_Pricing['Latitude']
# Out:
# 0        47.5112
# 1        47.7210
# 2        47.7379
# 3        47.5208
# 4        47.6168
#           ...
# 21608    47.6993
# 21609    47.5107
# 21610    47.5944
# 21611    47.5345
# 21612    47.5941
# Name: Latitude, Length: 21613, dtype: float64

# %%
House_Pricing['Longitude'] = House_Pricing['Longitude'].fillna(House_Pricing['Longitude'].median())
House_Pricing['Longitude']
# Out:
# 0       -122.257
# 1       -122.319
# 2       -122.233
# 3       -122.393
# 4       -122.045
#           ...
# 21608   -122.346
# 21609   -122.362
# 21610   -122.299
# 21611   -122.069
# 21612   -122.299
# Name: Longitude, Length: 21613, dtype: float64

# %%
House_Pricing.isna().sum()
# Out:
# ID                                           0
# Date House was Sold                          0
# Sale Price                                   0
# No of Bedrooms                               0
# No of Bathrooms                              0
# Flat Area (in Sqft)                          0
# Lot Area (in Sqft)                           0
# No of Floors                                 0
# Waterfront View                              0
# Condition of the House                       0
# Overall Grade                                0
# Area of the House from Basement (in Sqft)    0
# Basement Area (in Sqft)                      0
# Age of House (in Years)                      0
# Renovated Year                               0
# Zipcode                                      0
# Latitude                                     0
# Longitude                                    0
# Living Area after Renovation (in Sqft)       1
# Lot Area after Renovation (in Sqft)          0
# dtype: int64

# %%
House_Pricing['Living Area after Renovation (in Sqft)	'] = House_Pricing['Living Area after Renovation (in Sqft)'].fillna(House_Pricing['Living Area after Renovation (in Sqft)'].mean())
House_Pricing['Living Area after Renovation (in Sqft)	']
# Out:
# 0        1340.0
# 1        1690.0
# 2        2720.0
# 3        1360.0
# 4        1800.0
#           ...
# 21608    1530.0
# 21609    1830.0
# 21610    1020.0
# 21611    1410.0
# 21612    1020.0
# Name: Living Area after Renovation (in Sqft)\t, Length: 21613, dtype: float64

# %%
House_Pricing['Sale Price'] = House_Pricing['Sale Price'].fillna(House_Pricing['Sale Price'].mean())
House_Pricing['Sale Price']
# Out:
# 0        221900.0
# 1        538000.0
# 2        180000.0
# 3        604000.0
# 4        510000.0
#            ...
# 21608    360000.0
# 21609    400000.0
# 21610    402101.0
# 21611    400000.0
# 21612    325000.0
# Name: Sale Price, Length: 21613, dtype: float64

# %%
House_Pricing.isna().sum()
# Out:
# ID                                           0
# Date House was Sold                          0
# Sale Price                                   0
# No of Bedrooms                               0
# No of Bathrooms                              0
# Flat Area (in Sqft)                          0
# Lot Area (in Sqft)                           0
# No of Floors                                 0
# Waterfront View                              0
# Condition of the House                       0
# Overall Grade                                0
# Area of the House from Basement (in Sqft)    0
# Basement Area (in Sqft)                      0
# Age of House (in Years)                      0
# Renovated Year                               0
# Zipcode                                      0
# Latitude                                     0
# Longitude                                    0
# Living Area after Renovation (in Sqft)       1
# Lot Area after Renovation (in Sqft)          0
# ...

# %%
House_Pricing['Living Area after Renovation (in Sqft)'] = House_Pricing['Living Area after Renovation (in Sqft)'].fillna(House_Pricing['Living Area after Renovation (in Sqft)'].mean())
House_Pricing['Living Area after Renovation (in Sqft)']
# Out:
# 0        1340.0
# 1        1690.0
# 2        2720.0
# 3        1360.0
# 4        1800.0
#           ...
# 21608    1530.0
# 21609    1830.0
# 21610    1020.0
# 21611    1410.0
# 21612    1020.0
# Name: Living Area after Renovation (in Sqft), Length: 21613, dtype: float64

# %%
House_Pricing.isna().sum()
# Out:
# ID                                           0
# Date House was Sold                          0
# Sale Price                                   0
# No of Bedrooms                               0
# No of Bathrooms                              0
# Flat Area (in Sqft)                          0
# Lot Area (in Sqft)                           0
# No of Floors                                 0
# Waterfront View                              0
# Condition of the House                       0
# Overall Grade                                0
# Area of the House from Basement (in Sqft)    0
# Basement Area (in Sqft)                      0
# Age of House (in Years)                      0
# Renovated Year                               0
# Zipcode                                      0
# Latitude                                     0
# Longitude                                    0
# Living Area after Renovation (in Sqft)       0
# Lot Area after Renovation (in Sqft)          0
# ...

# %% [markdown]
# Outlier Removal

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.boxplot(House_Pricing['No of Bedrooms'])
# Out:
# <Axes: ylabel='No of Bedrooms'>

# %%
sns.boxplot(House_Pricing['No of Bathrooms'])
# Out:
# <Axes: ylabel='No of Bathrooms'>

# %%
sns.boxplot(House_Pricing['Flat Area (in Sqft)'])
# Out:
# <Axes: ylabel='Flat Area (in Sqft)'>

# %%
sns.boxplot(House_Pricing['Lot Area (in Sqft)'])
# Out:
# <Axes: ylabel='Lot Area (in Sqft)'>

# %%
sns.boxplot(House_Pricing['No of Floors'])
# Out:
# <Axes: ylabel='No of Floors'>

# %%
sns.boxplot(House_Pricing['Overall Grade'])
# Out:
# <Axes: ylabel='Overall Grade'>

# %%
sns.boxplot(House_Pricing['Area of the House from Basement (in Sqft)'])
# Out:
# <Axes: ylabel='Area of the House from Basement (in Sqft)'>

# %%
sns.boxplot(House_Pricing['Basement Area (in Sqft)'])
# Out:
# <Axes: ylabel='Basement Area (in Sqft)'>

# %%
sns.boxplot(House_Pricing['Age of House (in Years)'])
# Out:
# <Axes: ylabel='Age of House (in Years)'>

# %%
sns.boxplot(House_Pricing['Renovated Year'])
# Out:
# <Axes: ylabel='Renovated Year'>

# %%
sns.boxplot(House_Pricing['Zipcode'])
# Out:
# <Axes: ylabel='Zipcode'>

# %%
sns.boxplot(House_Pricing['Latitude'])
# Out:
# <Axes: ylabel='Latitude'>

# %%
sns.boxplot(House_Pricing['Longitude'])
# Out:
# <Axes: ylabel='Longitude'>

# %% [markdown]
# Encoding

# %%
House_Pricing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21613 non-null  int64
#  1   Date House was Sold                        21613 non-null  object
#  2   Sale Price                                 21613 non-null  float64
#  3   No of Bedrooms                             21613 non-null  int64
#  4   No of Bathrooms                            21613 non-null  float64
#  5   Flat Area (in Sqft)                        21613 non-null  float64
#  6   Lot Area (in Sqft)                         21613 non-null  float64
#  7   No of Floors                               21613 non-null  float64
#  8   Waterfront View                            21613 non-null  object
#  9   Condition of the House                     21613 non-null  object
# ...

# %%
House_Pricing['Waterfront View'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
waterfront_view = {'No':0,'Yes':1}
House_Pricing['Waterfront View'] = House_Pricing['Waterfront View'].map(waterfront_view)
House_Pricing['Waterfront View']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 21608    0
# 21609    0
# 21610    0
# 21611    0
# 21612    0
# Name: Waterfront View, Length: 21613, dtype: int64

# %%
House_Pricing['Condition of the House'].unique()
# Out:
# array(['Fair', 'Excellent', 'Good', 'Bad', 'Okay'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
label_enc = LabelEncoder()

# %%
House_Pricing['Condition of the House'] = label_enc.fit_transform(House_Pricing['Condition of the House'])
House_Pricing.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#    Waterfront View  Condition of the House  ...  \
# 0                0                       2  ...
# ...

# %%
House_Pricing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21613 non-null  int64
#  1   Date House was Sold                        21613 non-null  object
#  2   Sale Price                                 21613 non-null  float64
#  3   No of Bedrooms                             21613 non-null  int64
#  4   No of Bathrooms                            21613 non-null  float64
#  5   Flat Area (in Sqft)                        21613 non-null  float64
#  6   Lot Area (in Sqft)                         21613 non-null  float64
#  7   No of Floors                               21613 non-null  float64
#  8   Waterfront View                            21613 non-null  int64
#  9   Condition of the House                     21613 non-null  int64
# ...

# %%
House_Pricing['Waterfront View'].unique()
# Out:
# array([0, 1])

# %%
waterfront_view = {'No':0,'Yes':1}
House_Pricing['Waterfront View'] = House_Pricing['Waterfront View'].map(waterfront_view)
House_Pricing['Waterfront View']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 21608   NaN
# 21609   NaN
# 21610   NaN
# 21611   NaN
# 21612   NaN
# Name: Waterfront View, Length: 21613, dtype: float64

# %%
House_Pricing['Condition of the House'].unique()
# Out:
# array([2, 1, 3, 0, 4])

# %%
from sklearn.preprocessing import LabelEncoder
label_enc = LabelEncoder()

# %%
House_Pricing['Condition of the House'] = label_enc.fit_transform(House_Pricing['Condition of the House'])
House_Pricing.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#    Waterfront View  Condition of the House  ...  \
# 0              NaN                       2  ...
# ...

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler

# %%
min_max_scaler = MinMaxScaler(feature_range=(0,1))

# %%
num_cols = ['No of Bedrooms','No of Bathrooms','Flat Area (in Sqft)',
   'Lot Area (in Sqft)','No of Floors','Overall Grade',
   'Area of the House from Basement (in Sqft)','Basement Area (in Sqft)',
   'Age of House (in Years)','Renovated Year','Zipcode','Latitude',
   'Longitude','Living Area after Renovation (in Sqft)',
   'Lot Area after Renovation (in Sqft)']

# %%
House_Pricing[num_cols]=min_max_scaler.fit_transform(House_Pricing[num_cols])
House_Pricing
# Out:
#                ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0      7129300520     14 October 2017    221900.0        0.090909
# 1      6414100192    14 December 2017    538000.0        0.090909
# 2      5631500400    15 February 2016    180000.0        0.060606
# 3      2487200875    14 December 2017    604000.0        0.121212
# 4      1954400510    15 February 2016    510000.0        0.090909
# ...           ...                 ...         ...             ...
# 21608   263000018         14 May 2017    360000.0        0.090909
# 21609  6600060120    15 February 2016    400000.0        0.121212
# 21610  1523300141        14 June 2017    402101.0        0.060606
# 21611   291310100     15 January 2016    400000.0        0.090909
# 21612  1523300157     14 October 2017    325000.0        0.060606
#
#        No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0              0.12500             0.067170            0.003108           0.0
# ...

# %%
House_Pricing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21613 non-null  int64
#  1   Date House was Sold                        21613 non-null  object
#  2   Sale Price                                 21613 non-null  float64
#  3   No of Bedrooms                             21613 non-null  float64
#  4   No of Bathrooms                            21613 non-null  float64
#  5   Flat Area (in Sqft)                        21613 non-null  float64
#  6   Lot Area (in Sqft)                         21613 non-null  float64
#  7   No of Floors                               21613 non-null  float64
#  8   Waterfront View                            0 non-null      float64
#  9   Condition of the House                     21613 non-null  int64
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x = House_Pricing.drop(columns = ['Sale Price'])
y = House_Pricing['Sale Price']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

print("Shape of X_train:",x_train.shape)
print("Shape of X_test:",x_test.shape)
print("Shape of Y_train:",y_train.shape)
print("Shape of Y_test:",y_test.shape)
# Out:
# Shape of X_train: (17290, 20)
# Shape of X_test: (4323, 20)
# Shape of Y_train: (17290,)
# Shape of Y_test: (4323,)
