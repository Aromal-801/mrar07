# %% [markdown]
# <a href="https://colab.research.google.com/github/Aromal-801/mrar07/blob/main/Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Libraies

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression # LogisticRegression
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix
from sklearn.neighbors import KNeighborsClassifier #for k-NN
from sklearn.naive_bayes import GaussianNB #for naive - bayes
from sklearn.svm import SVC #for smv classification
from sklearn.tree import DecisionTreeClassifier # for decision tree
from sklearn.ensemble import RandomForestClassifier #for random forest

# %% [markdown]
# loading the dataset from google drive

# %%
# mounting the drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
filepath= '/content/drive/MyDrive/DSA(ICT)/Data Set/iris.csv'

df_iris = pd.read_csv(filepath)
df_iris.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %% [markdown]
# preprocessing

# %%
encoder = LabelEncoder()
df_iris['species'] = encoder.fit_transform(df_iris['species'])
df_iris.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0

# %% [markdown]
# Model building

# %%
#spilt data into train dataset
x= df_iris.drop('species',axis=1)
y= df_iris['species']

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
#building Logistic regression model
log_reg_model = LogisticRegression()
log_reg_model.fit(x_train,y_train) #training the model
y_pred = log_reg_model.predict(x_test) #predicting the test data
#evaluate the model
accuracy = accuracy_score(y_test,y_pred)
precision = precision_score(y_test,y_pred,average='weighted')
recall = recall_score(y_test,y_pred,average='weighted')

print("Accuracy:",accuracy)
print("Precision:",precision)
print("Recall:",recall)
# Out:
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0

# %%
#prediction using threshold
y_pred_threshold = log_reg_model.predict_proba(x_test)[:,1]
y_pred_threshold = (y_pred_threshold >= 0.5).astype(int)
#evaluate the model
accuracy_thresh = accuracy_score(y_test,y_pred_threshold)
precision_thresh = precision_score(y_test,y_pred_threshold,average='weighted')
recall_thresh = recall_score(y_test,y_pred_threshold,average='weighted')

print('Threshold value used =0.33')
print("Accuracy:",accuracy_thresh)
print("Precision:",precision_thresh)
print("Recall:",recall_thresh)
# Out:
# Threshold value used =0.33
# Accuracy: 0.6333333333333333
# Precision: 0.45873015873015877
# Recall: 0.6333333333333333
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# k-NN (k-nearest neighors)

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train,y_train) #training the model
y_pred_knn = knn.predict(x_test) #prediction
#evaluate the model
accuracy_thresh = accuracy_score(y_test,y_pred)
precision_thresh = precision_score(y_test,y_pred ,average='weighted')
recall_thresh = recall_score(y_test,y_pred ,average='weighted')

print("Accuracy:",accuracy)
print("Precision:",precision)
print("Recall:",recall)
# Out:
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0

# %% [markdown]
#   Naive-Bayes classification

# %%
nb_model = GaussianNB()
nb_model.fit(x_train,y_train) #training the model
y_pred_nb = nb_model.predict(x_test) #prediction
#Evaluation
accuracy_nb = accuracy_score(y_test,y_pred_nb)
precision_nb = precision_score(y_test,y_pred_nb,average='weighted')
recall_nb = recall_score(y_test,y_pred_nb,average='weighted')
print("Accuracy:",accuracy_nb)
print("Precision:",precision_nb)
print("Recall:",recall_nb)
# Out:
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0

# %% [markdown]
# SVM classifier

# %%
sv_model = SVC(kernel='linear')
sv_model.fit(x_train,y_train) #training the model
y_pred_sv = sv_model.predict(x_test) #prediction
#Evaluation
accuracy_sv = accuracy_score(y_test,y_pred_sv)
precision_sv = precision_score(y_test,y_pred_sv,average='weighted')
recall_sv = recall_score(y_test,y_pred_sv,average='weighted')
confusion_matrix_sv = confusion_matrix(y_test,y_pred_sv)
print("Confusion Matrix:",confusion_matrix_sv)
print("Accuracy:",accuracy_sv)
print("Precision:",precision_sv)
print("Recall:",recall_sv)
# Out:
# Confusion Matrix: [[10  0  0]
#  [ 0  9  0]
#  [ 0  0 11]]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0

# %% [markdown]
# Decision Tree

# %%
de_model = DecisionTreeClassifier()
de_model.fit(x_train,y_train) #training the model
y_pred_de = de_model.predict(x_test) #prediction
#Evaluation
accuracy_de = accuracy_score(y_test,y_pred=y_pred_de)
precision_de = precision_score(y_test,y_pred_de,average='weighted')
recall_de = recall_score(y_test,y_pred_de,average='weighted')
print("Accuracy:",accuracy_de)
print("Precision:",precision_de)
print("Recall:",recall_de)
# Out:
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0

# %% [markdown]
# RandomForest

# %%
rf_model = RandomForestClassifier()
rf_model.fit(x_train,y_train) #training the model
y_pred_rf = rf_model.predict(x_test) #prediction
#Evaluation
accuracy_rf = accuracy_score(y_test,y_pred_rf)
precision_rf = precision_score(y_test,y_pred_rf,average='weighted')
recall_rf = recall_score(y_test,y_pred_rf,average='weighted')
print("Accuracy:",accuracy_rf)
print("Precision:",precision_rf)
print("Recall:",recall_rf)
# Out:
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0

# %% [markdown]
# Data frame  Comparassion

# %%
df_data = {
    'Classifier': ['Logistic Regression', 'KNN', 'Naive Bayes', 'SVM', 'Decision Tree', 'Random Forest'],
    'Accuracy': [accuracy, accuracy, accuracy_nb, accuracy_sv, accuracy_de, accuracy_rf],
    'Precision': [precision, precision, precision_nb, precision_sv, precision_de, precision_rf],
    'Recall': [recall, recall, recall_nb, recall_sv, recall_de, recall_rf]
}
df_results = pd.DataFrame(df_data)
df_results
# Out:
#             Classifier  Accuracy  Precision  Recall
# 0  Logistic Regression       1.0        1.0     1.0
# 1                  KNN       1.0        1.0     1.0
# 2          Naive Bayes       1.0        1.0     1.0
# 3                  SVM       1.0        1.0     1.0
# 4        Decision Tree       1.0        1.0     1.0
# 5        Random Forest       1.0        1.0     1.0
